# %%
import pandas as pd
import json
import xmltodict
import re
import os
from pandas import json_normalize 
pd.set_option('display.max_columns', None)

# %%
import numpy as np
import json

class NpEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        if isinstance(obj, np.floating):
            return float(obj)
        if isinstance(obj, np.ndarray):
            return obj.tolist()
        return super(NpEncoder, self).default(obj)

# Your codes .... 
# json.dumps(data, cls=NpEncoder)

#read psi salary service data
psi = pd.read_csv('Lite PSI data.csv')


# get all the json request files

temp = pd.DataFrame()
final_req = []
path_to_json = r'C:/Users/mfajobi/Downloads/LL PSI/' #Path of json files
for file_name in [file for file in os.listdir(path_to_json) if file.endswith('.json')]:
  with open(path_to_json + file_name) as json_file:
    data = json.load(json_file)
          
          #del data['request']['input']['extractorData']
    json_data = data['request']['input']
       
  

          
    loans = psi['LoanId'].values
    for value in loans:
      if json_data['application']['loanId']==str(value):
        new = psi[psi['LoanId']==value]
        try:
          json_data.update({
        "salaryservice.minBalanceWk": str(new['minimumbalanceweekly'].values[0])}) 
        except:
          pass
        
        try:
          json_data.update({
        "salaryservice.averageCredit":str(new['averagecredit'].values[0])}) 
        except:
          pass
        
        try:
           json_data.update({
        "salaryservice.averageDebit": str(new['averagedebit'].values[0])}) 
        except:
          pass
        
        try:
          json_data.update({
        "salaryservice.closingBalance": str(new['closing_balance'].values[0])}) 
        except:
          pass
        
        try:
          json_data.update({
        "salaryservice.creGrEq2": str(new['cre_gr_eq_2'].values[0])}) 
        except:
          pass
        
        try:
          json_data.update({
        "salaryservice.dayDiffDebit": str(new['day_diff_debit'].values[0])}) 
        except:
          pass
        
        try:
          json_data.update({
        "salaryservice.minimumCredit": str(new['minimumcredit'].values[0])}) 
        except:
          pass
        
        try:
          json_data.update({
        "salaryservice.highestSingleDebitAmount4":str(new['highest_single_debit_amount_4'].values[0])})
        except:
          pass
        
        try:
          json_data.update({
        "salaryservice.monthlyCashFlow1": str(new['monthly_cash_flow_1'].values[0])}) 
        except:
          pass
        
        try:
          json_data.update({
        "salaryservice.monthlyCashFlow3": str(new['monthly_cash_flow_3'].values[0])})
        except: 
          pass
        
        try:
          json_data.update({
        "salaryservice.debitMonth": str(new['debitmonth'].values[0])})
        except:
          pass
        
        try:
          json_data.update({
        "salaryservice.loanCreditSum":str(new['loancreditsum'].values[0])})
        except:
          pass
        
        try:
           json_data.update({
        "salaryservice.monthlyElectricitySpending4": str(new['monthly_electricity_spending_4'].values[0])})
        except:
          pass
        
        try:
          json_data.update({
        "salaryservice.salariesPaymentDebitFreq3": str(new['salaries_payment_debit_freq_3'].values[0])})
        except:
          pass
        
        try:
          json_data.update({
        "salaryservice.totalDebit3": str(new['total_debit_3'].values[0])})
        except:
          pass
        
        try:
          json_data.update({
        "salaryservice.volOfAtmTransactionsCount2":str(new['vol_atm_transactions_count2'].values[0]) })
        except:
          pass
        
        try:
          json_data.update({
        "salaryservice.volOfAtmTransactionsCount4":str(new['vol_atm_transactions_count4'].values[0])})
        except:
          pass
        
        try:
          json_data.update({
        "salaryservice.avgNumDebitMn": str(new['avgnumdebitmn'].values[0])}) 
        except:
          pass
        
        try:
          json_data.update({
        "salaryservice.avgDebitMn": str(new['avgdebitmn'].values[0])}) 
        except:
          pass
        
        try:
          json_data.update({
        "salaryservice.totalCashFlow": str(new['total_cash_flow'].values[0])}) 
        except:
          pass
        
        try:
          json_data.update({
        "salaryservice.avgNumCreditWk": str(new['avgnumcreditwk'].values[0])}) 
        except:
          pass
        
        try:
          json_data.update({
        "salaryservice.avgNumDebitWk": str(new['avgnumdebitwk'].values[0])}) 
        except:
          pass
        
        try:
          json_data.update({
        "salaryservice.tvFreq4": str(new['tv_freq_4'].values[0])}) 
        except:
          pass
      
        id = json_data['application']['loanId']
        
        
  
  #write the updated json file to directory for unit testing
        with open(f"{id}.json", "w") as outfile:
          json.dump(json_data, outfile, cls=NpEncoder)

  #getting the batch files
    json_data = json_normalize(json_data)
    final_req.append(json_data)
    
df = pd.concat(final_req, sort=False)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-10-13f38ac1e462> in <module>
#      14 for file_name in [file for file in os.listdir(path_to_json) if file.endswith('.json')]:
#      15   with open(path_to_json + file_name) as json_file:
# ---> 16     data = json.load(json_file)
#      17
#      18           #del data['request']['input']['extractorData']
#
# c:\ProgramData\Anaconda3\lib\json\__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# c:\ProgramData\Anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
# ...

# %%
df.to_csv('sel batch test.csv')
